# %% [markdown]
# ### This project is used for coursera's capstone project.

# %%
import pandas as pd
import numpy as np
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
